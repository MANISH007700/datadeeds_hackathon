# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\MANISH SHARMA\Desktop\datasets\datadeeds_dataset.csv")
df
# Out:
#        country_region_code country_region sub_region_1    sub_region_2  \
# 0                       IN          India          NaN             NaN
# 1                       IN          India          NaN             NaN
# 2                       IN          India          NaN             NaN
# 3                       IN          India          NaN             NaN
# 4                       IN          India          NaN             NaN
# ...                    ...            ...          ...             ...
# 137669                  IN          India  West Bengal  West Medinipur
# 137670                  IN          India  West Bengal  West Medinipur
# 137671                  IN          India  West Bengal  West Medinipur
# 137672                  IN          India  West Bengal  West Medinipur
# 137673                  IN          India  West Bengal  West Medinipur
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# ...

# %% [markdown]
# ## checking nan values

# %%
import missingno as msg
msg.matrix(df)

# %% [markdown]
# ### As we can see , that column metro_area , iso_code and Census_fips_code has missing value >99% ,So we shall drop them !

# %%
df.drop(["metro_area","iso_3166_2_code","census_fips_code"], axis =1 , inplace = True)

# %%
df.head(10)
# Out:
#   country_region_code country_region sub_region_1 sub_region_2        date  \
# 0                  IN          India          NaN          NaN  2020-02-15
# 1                  IN          India          NaN          NaN  2020-02-16
# 2                  IN          India          NaN          NaN  2020-02-17
# 3                  IN          India          NaN          NaN  2020-02-18
# 4                  IN          India          NaN          NaN  2020-02-19
# 5                  IN          India          NaN          NaN  2020-02-20
# 6                  IN          India          NaN          NaN  2020-02-21
# 7                  IN          India          NaN          NaN  2020-02-22
# 8                  IN          India          NaN          NaN  2020-02-23
# 9                  IN          India          NaN          NaN  2020-02-24
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                1.0
# ...

# %% [markdown]
# # We will start with Country Region Code

# %%
df["country_region_code"]
# Out:
# 0         IN
# 1         IN
# 2         IN
# 3         IN
# 4         IN
#           ..
# 137669    IN
# 137670    IN
# 137671    IN
# 137672    IN
# 137673    IN
# Name: country_region_code, Length: 137674, dtype: object

# %%
df["country_region_code"].value_counts()
# Out:
# IN    137674
# Name: country_region_code, dtype: int64

# %%
sb.countplot(df["country_region_code"])
plt.grid()
plt.show()

# %% [markdown]
# ### So we have only one country-region-code -- India

# %% [markdown]
# # Lets jump to country_region

# %%
df["country_region"]
# Out:
# 0         India
# 1         India
# 2         India
# 3         India
# 4         India
#           ...
# 137669    India
# 137670    India
# 137671    India
# 137672    India
# 137673    India
# Name: country_region, Length: 137674, dtype: object

# %%
df["country_region"].value_counts()
# Out:
# India    137674
# Name: country_region, dtype: int64

# %%
sb.countplot(df["country_region"])
plt.grid()
plt.show()

# %% [markdown]
# ### So we have only one country region -- India

# %% [markdown]
# # Go for the 3rd column (Sub region)

# %%
df["sub_region_1"]
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#              ...
# 137669    West Bengal
# 137670    West Bengal
# 137671    West Bengal
# 137672    West Bengal
# 137673    West Bengal
# Name: sub_region_1, Length: 137674, dtype: object

# %% [markdown]
# ### Check nan values

# %%
df["sub_region_1"].isna().sum()
# Out:
# 207

# %% [markdown]
# ### Since 207 is a very small values compared to 1.3L , we are gonna drop that row

# %%
df.dropna(subset = ["sub_region_1"], inplace=True)

# %%
df["sub_region_1"].isna().sum()
# Out:
# 0

# %%
plt.figure(figsize = (9,10))
sb.countplot(df["sub_region_1"])
plt.grid()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### We can see that in terms of region, Uttar Pradesh Stands first and Madhya pradesh at 2nd

# %% [markdown]
# ### We shall take the top 10 region , and replace rest everything with -1

# %%
df["sub_region_1"].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Daman and Diu', 'Delhi',
#        'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df["sub_region_1"] = df["sub_region_1"].replace("Uttar Pradesh" ,10)
df["sub_region_1"] = df["sub_region_1"].replace("Madhya Pradesh" ,9)
df["sub_region_1"] = df["sub_region_1"].replace("Bihar" ,8)
df["sub_region_1"] = df["sub_region_1"].replace("Maharashtra" ,7)
df["sub_region_1"] = df["sub_region_1"].replace("Gujarat" ,6)
df["sub_region_1"] = df["sub_region_1"].replace("Rajasthan" ,5)
df["sub_region_1"] = df["sub_region_1"].replace("Tamil Nadu" ,4)
df["sub_region_1"] = df["sub_region_1"].replace("Karnataka" ,3)
df["sub_region_1"] = df["sub_region_1"].replace("Odisha" ,2)
df["sub_region_1"] = df["sub_region_1"].replace("Chhattisgarh" ,1)
df["sub_region_1"] = df["sub_region_1"].replace("Andhra Pradesh" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Arunachal Pradesh" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Chandigarh" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Andaman and Nicobar Islands" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Dadra and Nagar Haveli" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Daman and Diu" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Delhi" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Goa" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Haryana" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Himachal Pradesh" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Jammu and Kashmir" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Jharkhand" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Kerala" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Lakshadweep" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Manipur" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Meghalaya" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Mizoram" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Nagaland" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Puducherry" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Punjab" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Sikkim" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Telangana" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Tripura" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("Uttarakhand" ,-1)
df["sub_region_1"] = df["sub_region_1"].replace("West Bengal" ,-1)

# %%
df
# Out:
#        country_region_code country_region sub_region_1    sub_region_2  \
# 207                     IN          India           -1             NaN
# 208                     IN          India           -1             NaN
# 209                     IN          India           -1             NaN
# 210                     IN          India           -1             NaN
# 211                     IN          India           -1             NaN
# ...                    ...            ...          ...             ...
# 137669                  IN          India           -1  West Medinipur
# 137670                  IN          India           -1  West Medinipur
# 137671                  IN          India           -1  West Medinipur
# 137672                  IN          India           -1  West Medinipur
# 137673                  IN          India           -1  West Medinipur
#
#               date  retail_and_recreation_percent_change_from_baseline  \
# ...

# %% [markdown]
# # Lets check sub_region_2

# %%
df['sub_region_2']
# Out:
# 207                  NaN
# 208                  NaN
# 209                  NaN
# 210                  NaN
# 211                  NaN
#                ...
# 137669    West Medinipur
# 137670    West Medinipur
# 137671    West Medinipur
# 137672    West Medinipur
# 137673    West Medinipur
# Name: sub_region_2, Length: 137467, dtype: object

# %%
plt.figure(figsize = (9,10))
sb.countplot(df["sub_region_2"])
plt.grid()
plt.xticks(rotation = 90)
plt.show()

# %%
print(len(df["sub_region_2"].unique()))
# Out:
# 628

# %% [markdown]
# ### 628 unique values , hence we will drop it !

# %%
df.drop(["sub_region_2"], axis =1 , inplace = True)

# %% [markdown]
# # lets check for dates

# %%
df["date"]
# Out:
# 207       2020-02-15
# 208       2020-02-16
# 209       2020-02-17
# 210       2020-02-18
# 211       2020-02-19
#              ...
# 137669    2020-09-04
# 137670    2020-09-05
# 137671    2020-09-06
# 137672    2020-09-07
# 137673    2020-09-08
# Name: date, Length: 137467, dtype: object

# %%
print("max date" , df["date"].max())
print("min date" , df["date"].min())
# Out:
# max date 2020-09-08
# min date 2020-02-15

# %% [markdown]
# # convert into datetime index

# %%
df['date'] = pd.DatetimeIndex(df['date']).day
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month

# %%
print((df["date"].dtype))
# Out:
# int64

# %% [markdown]
# # lets check for retail_and_recreation_percent_change_from_baseline

# %%
df["retail_and_recreation_percent_change_from_baseline"]
# Out:
# 207        1.0
# 208        0.0
# 209       -1.0
# 210       -2.0
# 211       -5.0
#           ...
# 137669   -30.0
# 137670   -28.0
# 137671   -29.0
# 137672   -63.0
# 137673   -31.0
# Name: retail_and_recreation_percent_change_from_baseline, Length: 137467, dtype: float64

# %%
df["retail_and_recreation_percent_change_from_baseline"].isna().sum()
# Out:
# 9064

# %%
df.dropna(subset = ["retail_and_recreation_percent_change_from_baseline"], inplace=True)

# %%
sb.distplot(df["retail_and_recreation_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.boxplot(df["retail_and_recreation_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# ## remove outliers

# %%
df = df[(df["retail_and_recreation_percent_change_from_baseline"] >-100) & (df["retail_and_recreation_percent_change_from_baseline"] < 20)]

# %%
sb.boxplot(df["retail_and_recreation_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.distplot(df["retail_and_recreation_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# # Lets jump to grocery_and_pharmacy_percent_change_from_baseline

# %%
df["grocery_and_pharmacy_percent_change_from_baseline"]
# Out:
# 207       -9.0
# 208       -6.0
# 209        2.0
# 210       12.0
# 211        9.0
#           ...
# 137669     5.0
# 137670     6.0
# 137671    14.0
# 137672   -52.0
# 137673     4.0
# Name: grocery_and_pharmacy_percent_change_from_baseline, Length: 127733, dtype: float64

# %%
df["grocery_and_pharmacy_percent_change_from_baseline"].isna().sum()
# Out:
# 6120

# %%
df.dropna(subset = ["grocery_and_pharmacy_percent_change_from_baseline"]  , inplace = True)
# Out:
# C:\Users\MANISH SHARMA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df["grocery_and_pharmacy_percent_change_from_baseline"].isna().sum()
# Out:
# 0

# %%
sb.distplot(df["grocery_and_pharmacy_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.boxplot(df["grocery_and_pharmacy_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# ## remove outliers

# %%
df = df[(df["grocery_and_pharmacy_percent_change_from_baseline"] >-100) & (df["grocery_and_pharmacy_percent_change_from_baseline"] < 80)]

# %%
sb.boxplot(df["grocery_and_pharmacy_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.distplot(df["grocery_and_pharmacy_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# # lets go for parks_percent_change_from_baseline

# %%
df["parks_percent_change_from_baseline"]
# Out:
# 207        5.0
# 208        1.0
# 209        5.0
# 210       -4.0
# 211       -6.0
#           ...
# 137669    -1.0
# 137670    -1.0
# 137671    -7.0
# 137672   -11.0
# 137673     6.0
# Name: parks_percent_change_from_baseline, Length: 118936, dtype: float64

# %%
df["parks_percent_change_from_baseline"].isna().sum()
# Out:
# 1085

# %%
df.dropna(subset = ["parks_percent_change_from_baseline"]  , inplace = True)
# Out:
# C:\Users\MANISH SHARMA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sb.distplot(df["parks_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.boxplot(df["parks_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# ## remove outliers

# %%
df = df[(df["parks_percent_change_from_baseline"] >-100) & (df["parks_percent_change_from_baseline"] < 90)]

# %%
sb.boxplot(df["parks_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.distplot(df["parks_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# # now for transit_stations_percent_change_from_baseline

# %%
df["transit_stations_percent_change_from_baseline"]
# Out:
# 207       -2.0
# 208        2.0
# 209        1.0
# 210       -1.0
# 211        2.0
#           ...
# 137669   -34.0
# 137670   -36.0
# 137671   -34.0
# 137672   -72.0
# 137673   -37.0
# Name: transit_stations_percent_change_from_baseline, Length: 117154, dtype: float64

# %%
df["transit_stations_percent_change_from_baseline"].isna().sum()
# Out:
# 369

# %%
df.dropna(subset = ["transit_stations_percent_change_from_baseline"]  , inplace = True)
# Out:
# C:\Users\MANISH SHARMA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sb.distplot(df["transit_stations_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.boxplot(df["transit_stations_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# ## remove outliers

# %%
df = df[(df["transit_stations_percent_change_from_baseline"] >-100) & (df["transit_stations_percent_change_from_baseline"] < 30)]

# %%
sb.boxplot(df["transit_stations_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.distplot(df["transit_stations_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# # lets go for workplaces_percent_change_from_baseline

# %%
df["workplaces_percent_change_from_baseline"]
# Out:
# 207        6.0
# 208        4.0
# 209        6.0
# 210        4.0
# 211        4.0
#           ...
# 137669   -16.0
# 137670   -11.0
# 137671    -2.0
# 137672   -49.0
# 137673   -23.0
# Name: workplaces_percent_change_from_baseline, Length: 116399, dtype: float64

# %%
df["workplaces_percent_change_from_baseline"].isna().sum()
# Out:
# 0

# %%
sb.distplot(df["workplaces_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.boxplot(df["workplaces_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# ## remove outliers

# %%
df = df[(df["workplaces_percent_change_from_baseline"] >-70) & (df["workplaces_percent_change_from_baseline"] < 38)]

# %%
sb.boxplot(df["workplaces_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.distplot(df["workplaces_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# # now for residential_percent_change_from_baseline

# %%
df["residential_percent_change_from_baseline"]
# Out:
# 207        2.0
# 208        NaN
# 209        1.0
# 210        3.0
# 211        1.0
#           ...
# 137669    14.0
# 137670    12.0
# 137671    11.0
# 137672    26.0
# 137673    12.0
# Name: residential_percent_change_from_baseline, Length: 113948, dtype: float64

# %%
df["residential_percent_change_from_baseline"].isna().sum()
# Out:
# 165

# %%
df.dropna(subset = ["residential_percent_change_from_baseline"]  , inplace = True)
# Out:
# C:\Users\MANISH SHARMA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df["residential_percent_change_from_baseline"].isna().sum()
# Out:
# 0

# %%
sb.distplot(df["residential_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.boxplot(df["residential_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# ## remove outliers

# %%
df = df[(df["residential_percent_change_from_baseline"] >-10) & (df["residential_percent_change_from_baseline"] < 40)]

# %%
sb.boxplot(df["residential_percent_change_from_baseline"])
plt.grid()
plt.show()

# %%
sb.distplot(df["residential_percent_change_from_baseline"])
plt.grid()
plt.show()

# %% [markdown]
# ## Now time for encoding

# %%
df["country_region_code"] = df["country_region_code"].replace("IN" ,1)
df["country_region"] = df["country_region"].replace("India" ,1)
# Out:
# C:\Users\MANISH SHARMA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\MANISH SHARMA\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Since we need to look for the stay option , we will take "residential_percent_change_from_baseline" as our target cols##

# %%
df["sub_region_1"]
# Out:
# 207       -1
# 209       -1
# 210       -1
# 211       -1
# 212       -1
#           ..
# 137669    -1
# 137670    -1
# 137671    -1
# 137672    -1
# 137673    -1
# Name: sub_region_1, Length: 113735, dtype: object

# %%
df["sub_region_1"] = df["sub_region_1"].replace("Assam",8)
# Out:
# C:\Users\MANISH SHARMA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Now for some findings

# %%
plt.figure(figsize = (10,10))

sb.heatmap(df.corr() , annot = True)

# %%
work place and transit with 77 % relation

# %%
x = df.drop(["residential_percent_change_from_baseline"] , axis =1)
y = df["residential_percent_change_from_baseline"]

# %%
x
# Out:
#         country_region_code  country_region  sub_region_1  date  \
# 207                       1               1            -1    15
# 209                       1               1            -1    17
# 210                       1               1            -1    18
# 211                       1               1            -1    19
# 212                       1               1            -1    20
# ...                     ...             ...           ...   ...
# 137669                    1               1            -1     4
# 137670                    1               1            -1     5
# 137671                    1               1            -1     6
# 137672                    1               1            -1     7
# 137673                    1               1            -1     8
#
#         retail_and_recreation_percent_change_from_baseline  \
# 207                                                   1.0
# 209                                                  -1.0
# ...

# %%
y
# Out:
# 207        2.0
# 209        1.0
# 210        3.0
# 211        1.0
# 212        1.0
#           ...
# 137669    14.0
# 137670    12.0
# 137671    11.0
# 137672    26.0
# 137673    12.0
# Name: residential_percent_change_from_baseline, Length: 113735, dtype: float64

# %%
print(x.shape  , y.shape)
# Out:
# (113735, 11) (113735,)

# %% [markdown]
# ## We will use a Regression Model of RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
rfr = RandomForestRegressor()

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size= 0.3,random_state =100)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (79614, 11)
# (34121, 11)
# (79614,)
# (34121,)

# %%
# training
print(rfr.fit(x_train , y_train))
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Use metrics mean_squared_error

# %%
from sklearn.metrics import mean_squared_error , r2_score

# %%
print(mean_squared_error(rfr.predict(x_train) , y_train))
# Out:
# 0.7077036316354887

# %%
print(mean_squared_error(rfr.predict(x_test) , y_test))
# Out:
# 4.992727214395501

# %%
#test data

print(r2_score(rfr.predict(x_test) , y_test))
# Out:
# 0.9327459886921283

# %%
#train data

print(r2_score(rfr.predict(x_train) , y_train))
# Out:
# 0.990912344520581

# %%
sb.distplot(rfr.predict(x_train))

# %%
sb.distplot(y_train)

# %%
sb.distplot(rfr.predict(x_test))

# %%
sb.distplot(y_test)

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## work place and grocery are in 62 % related to each other
# ## transit and grocery are in 53 % related to each other
# ## transit with retail are in 81 % related to each other
